# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 80% de los datos para entrenamiento y un 20% de los datos para validación
valid_idx  =  range ( len ( df ) - 57 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['ESTRES_PERCIBIDO', 'CAPE_POS_MALESTAR', 'CAPE_NEG_MALESTAR', 'CSI_APOYOSOC', 'SCL90_DEPRE', 'CSI_RESPROBL', 'SCL90_PSICOT', 'CSI_RETISOC', 'CSL90_HOSTIL', 'CAPE_NEG_FREC', 'CSI_PENSDESID', 'CAPE_POSIT_FREC', 'SCL90_IDEA_PARAN', 'CSI_AUTOCRIT', 'TRAUMA_FRECUENCIA', 'CSI_EXPEMOC', 'CAPE_DEPRE_FREC', 'CAPE_DEPRE_MALESTAR', 'SCL90_SOMAT', 'SCL90_ANSIE', 'CSI_REESTCOGN', 'SCL90_OBS_COMP', 'CSL90_SENS_INT', 'TRAUMA_AFECTACION', 'CSI_EVITPROBL', 'SCL90_ANS_FOB', 'ANSIEDADRASGO']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[-1.487604 -0.899782 -1.025957 -0.240362 ... -1.323901 -0.545358 -0.517128  0.178179]
#  [ 1.456237  0.346945  3.148408 -0.911615 ...  0.466996  0.106226  0.758189  1.149676]
#  [ 0.749715 -0.333087  1.24272  -0.743802 ...  0.211154  0.975005 -0.33494  -0.145654]
#  [ 0.396454  2.613722  0.698237 -0.743802 ... -1.068058 -0.328163  1.851317 -0.30757 ]
#  [ 1.456237  2.160367  1.061226 -1.582869 ...  0.765479  1.626588  0.940377  0.502011]]
# [0 2 0 0 1]

# %%
learn = tabular_learner(data, layers=[100,50], metrics=accuracy)
learn.fit(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.018294</td>
#       <td>0.997803</td>
#       <td>0.596491</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.867090</td>
#       <td>0.955797</td>
#       <td>0.614035</td>
#       <td>02:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ESTRES_PERCIBIDO</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>CSI_APOYOSOC</th>
#       <th>SCL90_DEPRE</th>
#       <th>CSI_RESPROBL</th>
#       <th>SCL90_PSICOT</th>
#       <th>CSI_RETISOC</th>
#       <th>CSL90_HOSTIL</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>CSI_PENSDESID</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>CSI_EXPEMOC</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>SCL90_SOMAT</th>
#       <th>SCL90_ANSIE</th>
#       <th>CSI_REESTCOGN</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>CSL90_SENS_INT</th>
#       <th>TRAUMA_AFECTACION</th>
#       <th>CSI_EVITPROBL</th>
#       <th>SCL90_ANS_FOB</th>
#       <th>ANSIEDADRASGO</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.8675</td>
#       <td>1.3670</td>
#       <td>0.9705</td>
#       <td>-1.0794</td>
#       <td>-0.0581</td>
#       <td>-0.3240</td>
#       <td>0.6097</td>
#       <td>-0.1961</td>
#       <td>0.4484</td>
#       <td>0.3031</td>
#       <td>-0.7051</td>
#       <td>0.6420</td>
#       <td>1.0269</td>
#       <td>0.6547</td>
#       <td>0.2933</td>
#       <td>-1.7118</td>
#       <td>0.3497</td>
#       <td>0.8637</td>
#       <td>-0.8431</td>
#       <td>-0.1922</td>
#       <td>-0.2256</td>
#       <td>0.1981</td>
#       <td>1.0002</td>
#       <td>0.8081</td>
#       <td>-0.3282</td>
#       <td>-0.6993</td>
#       <td>-0.1457</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td