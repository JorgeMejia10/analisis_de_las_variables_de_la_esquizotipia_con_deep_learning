# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 85% de los datos para entrenamiento y un 15% de los datos para validación
valid_idx  =  range ( len ( df ) - 43 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['SCL90_ANS_FOB', 'CSI_AUTOCRIT', 'SCL90_OBS_COMP', 'CSI_EVITPROBL', 'CSI_PENSDESID', 'CAPE_POS_MALESTAR', 'SCL90_DEPRE', 'TRAUMA_FRECUENCIA', 'CSL90_SENS_INT', 'CAPE_DEPRE_FREC', 'CSL90_HOSTIL', 'CSI_RESPROBL', 'ESTRES_PERCIBIDO', 'CSI_APOYOSOC', 'CSI_REESTCOGN', 'SCL90_ANSIE', 'CAPE_NEG_FREC', 'SCL90_SOMAT', 'CAPE_NEG_MALESTAR', 'SCL90_PSICOT', 'CAPE_DEPRE_MALESTAR', 'CAPE_POSIT_FREC', 'TRAUMA_AFECTACION', 'ANSIEDADRASGO', 'SCL90_IDEA_PARAN', 'CSI_EXPEMOC', 'CSI_RETISOC']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[-0.688022  0.145201 -1.186487  2.097442 ...  0.504934 -0.897894  1.296075 -1.458241]
#  [ 0.054217 -1.266155 -0.754876 -0.324356 ... -0.718996 -0.70256   0.538993 -0.612026]
#  [-0.688022 -0.207638 -0.970681  0.556298 ... -0.871988 -0.70256  -0.028819  0.657297]
#  [-0.502462 -0.736896  0.432055 -0.54452  ...  0.657926 -0.507226 -0.21809  -0.188918]
#  [ 1.909815  0.321621  0.971569  0.776461 ...  1.269891  1.446116 -0.40736   0.022635]]
# [0 0 0 0 1]

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.136207</td>
#       <td>0.960766</td>
#       <td>0.627907</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.944164</td>
#       <td>0.950372</td>
#       <td>0.651163</td>
#       <td>03:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>SCL90_ANS_FOB</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>CSI_EVITPROBL</th>
#       <th>CSI_PENSDESID</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>SCL90_DEPRE</th>
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>CSL90_SENS_INT</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>CSL90_HOSTIL</th>
#       <th>CSI_RESPROBL</th>
#       <th>ESTRES_PERCIBIDO</th>
#       <th>CSI_APOYOSOC</th>
#       <th>CSI_REESTCOGN</th>
#       <th>SCL90_ANSIE</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>SCL90_SOMAT</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>SCL90_PSICOT</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>TRAUMA_AFECTACION</th>
#       <th>ANSIEDADRASGO</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>CSI_EXPEMOC</th>
#       <th>CSI_RETISOC</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.6880</td>
#       <td>2.0858</td>
#       <td>0.3242</td>
#       <td>1.6571</td>
#       <td>0.7717</td>
#       <td>0.2197</td>
#       <td>0.8337</td>
#       <td>-0.3719</td>
#       <td>-0.6075</td>
#       <td>0.1242</td>
#       <td>-0.6153</td>
#       <td>-0.7208</td>
#       <td>1.5861</td>
#       <td>1.6052</td>
#       <td>-0.3993</td>
#       <td>0.6526</td>
#       <td>0.0361</td>
#       <td>0.5156</td>
#       <td>-0.0425</td>
#       <td>0.5051</td>
#       <td>0.4405</td>
#       <td>-0.1545</td>
#       <td>-0.1317</td>
#       <td>0.3519</td>
#       <td>-0.8979</td>
#       <td>0.3497</td>
#       <td>-0.8236</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td