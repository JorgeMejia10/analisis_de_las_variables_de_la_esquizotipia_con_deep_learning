# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 95% de los datos para entrenamiento y un 5% de los datos para validación
valid_idx  =  range ( len ( df ) - 14 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['CSI_REESTCOGN', 'SCL90_SOMAT', 'CSL90_HOSTIL', 'SCL90_IDEA_PARAN', 'CAPE_DEPRE_FREC', 'CSI_EVITPROBL', 'CSI_AUTOCRIT', 'CAPE_POS_MALESTAR', 'TRAUMA_FRECUENCIA', 'CSI_APOYOSOC', 'CSI_RESPROBL', 'SCL90_ANSIE', 'ANSIEDADRASGO', 'CAPE_NEG_FREC', 'TRAUMA_AFECTACION', 'CAPE_NEG_MALESTAR', 'CSI_RETISOC', 'CSI_EXPEMOC', 'CSI_PENSDESID', 'CAPE_DEPRE_MALESTAR', 'SCL90_DEPRE', 'CAPE_POSIT_FREC', 'SCL90_PSICOT', 'CSL90_SENS_INT', 'ESTRES_PERCIBIDO', 'SCL90_OBS_COMP', 'SCL90_ANS_FOB']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[ 0.163014 -0.953292 -0.850549 -0.31388  ... -1.021665 -0.95565  -1.19836  -0.697683]
#  [ 0.724275 -1.049399 -0.850549 -0.898642 ... -1.021665 -0.476062 -1.19836  -0.697683]
#  [-0.772423  0.968839 -0.195787 -0.31388  ... -0.343877  0.123423 -0.240611 -0.146027]
#  [ 1.472624 -1.049399 -0.632295 -0.898642 ... -0.343877 -0.595959 -0.347027 -0.697683]
#  [-0.211161  1.064945  0.458975  1.635327 ...  0.87614   0.722909  0.717138 -0.513797]]
# [0 1 0 0 1]

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.995965</td>
#       <td>0.902956</td>
#       <td>0.785714</td>
#       <td>02:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.830996</td>
#       <td>0.807864</td>
#       <td>0.857143</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.741124</td>
#       <td>0.709646</td>
#       <td>0.785714</td>
#       <td>02:53</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.670203</td>
#       <td>0.607854</td>
#       <td>0.857143</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.602130</td>
#       <td>0.539633</td>
#       <td>0.785714</td>
#       <td>02:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>CSI_REESTCOGN</th>
#       <th>SCL90_SOMAT</th>
#       <th>CSL90_HOSTIL</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>CSI_EVITPROBL</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>CSI_APOYOSOC</th>
#       <th>CSI_RESPROBL</th>
#       <th>SCL90_ANSIE</th>
#       <th>ANSIEDADRASGO</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>TRAUMA_AFECTACION</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>CSI_RETISOC</th>
#       <th>CSI_EXPEMOC</th>
#       <th>CSI_PENSDESID</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>SCL90_DEPRE</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>SCL90_PSICOT</th>
#       <th>CSL90_SENS_INT</th>
#       <th>ESTRES_PERCIBIDO</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>SCL90_ANS_FOB</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.9595</td>
#       <td>-0.9533</td>
#       <td>-0.4140</td>
#       <td>-0.7037</td>
#       <td>0.1186</td>
#       <td>-1.0039</td>
#       <td>0.1653</td>
#       <td>-0.2276</td>
#       <td>0.2974</td>
#       <td>-0.2470</td>
#       <td>-0.0714</td>
#       <td>-0.3271</td>
#       <td>-0.7164</td>
#       <td>0.5755</td>
#       <td>-0.2028</td>
#       <td>1.8127</td>
#       <td>-0.6265</td>
#       <td>-0.3887</td>
#       <td>-0.0166</td>
#       <td>0.2844</td>
#       <td>-0.2235</td>
#       <td>-0.4561</td>
#       <td>-0.3070</td>
#       <td>-0.7505</td>
#       <td>0.1234</td>
#       <td>0.0786</td>
#       <td>-0.6977</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td