# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 95% de los datos para entrenamiento y un 5% de los datos para validación
valid_idx  =  range ( len ( df ) - 14 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['SCL90_ANSIE', 'SCL90_OBS_COMP', 'CSI_REESTCOGN', 'TRAUMA_FRECUENCIA', 'ANSIEDADRASGO', 'SCL90_DEPRE', 'CAPE_DEPRE_FREC', 'CSI_RESPROBL', 'CSI_PENSDESID', 'CAPE_POSIT_FREC', 'SCL90_SOMAT', 'CAPE_NEG_MALESTAR', 'CSI_AUTOCRIT', 'CAPE_DEPRE_MALESTAR', 'CSI_EXPEMOC', 'CSI_APOYOSOC', 'SCL90_ANS_FOB', 'CAPE_NEG_FREC', 'CSI_RETISOC', 'CSL90_HOSTIL', 'SCL90_PSICOT', 'TRAUMA_AFECTACION', 'CAPE_POS_MALESTAR', 'SCL90_IDEA_PARAN', 'CSI_EVITPROBL', 'CSL90_SENS_INT', 'ESTRES_PERCIBIDO']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[ 0.628309  0.823554  0.350101 -0.536478 ...  1.635327 -0.115173  1.553927 -0.476062]
#  [ 0.389455  0.823554 -0.024074 -1.277669 ...  1.245486  0.773541  0.87614  -0.236268]
#  [-0.685388 -0.87911  -1.520772  0.390011 ... -0.898642 -1.003888 -0.75055   0.842806]
#  [-0.088253  0.291472 -0.772423  0.48266  ...  0.075962  0.329184 -0.343877 -0.116371]
#  [-0.685388  0.397888  1.846799  1.316499 ...  0.075962  0.995719 -0.072762 -1.675033]]
# [1 0 0 0 1]

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.955251</td>
#       <td>0.898177</td>
#       <td>0.714286</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.809121</td>
#       <td>0.747818</td>
#       <td>0.857143</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.723177</td>
#       <td>0.642305</td>
#       <td>0.857143</td>
#       <td>02:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.645983</td>
#       <td>0.555539</td>
#       <td>0.785714</td>
#       <td>03:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.582324</td>
#       <td>0.499772</td>
#       <td>0.857143</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.525022</td>
#       <td>0.461668</td>
#       <td>0.857143</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.474540</td>
#       <td>0.403636</td>
#       <td>0.785714</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.434203</td>
#       <td>0.402751</td>
#       <td>0.857143</td>
#       <td>02:46</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.387863</td>
#       <td>0.344341</td>
#       <td>0.857143</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.350374</td>
#       <td>0.375682</td>
#       <td>0.785714</td>
#       <td>02:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>SCL90_ANSIE</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>CSI_REESTCOGN</th>
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>ANSIEDADRASGO</th>
#       <th>SCL90_DEPRE</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>CSI_RESPROBL</th>
#       <th>CSI_PENSDESID</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>SCL90_SOMAT</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>CSI_EXPEMOC</th>
#       <th>CSI_APOYOSOC</th>
#       <th>SCL90_ANS_FOB</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>CSI_RETISOC</th>
#       <th>CSL90_HOSTIL</th>
#       <th>SCL90_PSICOT</th>
#       <th>TRAUMA_AFECTACION</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>CSI_EVITPROBL</th>
#       <th>CSL90_SENS_INT</th>
#       <th>ESTRES_PERCIBIDO</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.3271</td>
#       <td>0.0786</td>
#       <td>-0.9595</td>
#       <td>0.2974</td>
#       <td>-0.7164</td>
#       <td>-0.2235</td>
#       <td>0.1186</td>
#       <td>-0.0714</td>
#       <td>-0.0166</td>
#       <td>-0.4561</td>
#       <td>-0.9533</td>
#       <td>1.8127</td>
#       <td>0.1653</td>
#       <td>0.2844</td>
#       <td>-0.3887</td>
#       <td>-0.2470</td>
#       <td>-0.6977</td>
#       <td>0.5755</td>
#       <td>-0.6265</td>
#       <td>-0.4140</td>
#       <td>-0.3070</td>
#       <td>-0.2028</td>
#       <td>-0.2276</td>
#       <td>-0.7037</td>
#       <td>-1.0039</td>
#       <td>-0.7505</td>
#       <td>0.1234</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td