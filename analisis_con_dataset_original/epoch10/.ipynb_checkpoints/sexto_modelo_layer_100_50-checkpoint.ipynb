# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 90% de los datos para entrenamiento y un 10% de los datos para validación
valid_idx  =  range ( len ( df ) - 29 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['TRAUMA_AFECTACION', 'CSI_REESTCOGN', 'SCL90_DEPRE', 'SCL90_OBS_COMP', 'CSL90_HOSTIL', 'SCL90_ANSIE', 'ANSIEDADRASGO', 'CSI_RESPROBL', 'CAPE_NEG_FREC', 'CSI_EVITPROBL', 'CSL90_SENS_INT', 'CSI_PENSDESID', 'SCL90_IDEA_PARAN', 'CAPE_DEPRE_MALESTAR', 'SCL90_SOMAT', 'CAPE_DEPRE_FREC', 'SCL90_ANS_FOB', 'CAPE_NEG_MALESTAR', 'CSI_APOYOSOC', 'SCL90_PSICOT', 'TRAUMA_FRECUENCIA', 'ESTRES_PERCIBIDO', 'CAPE_POSIT_FREC', 'CSI_RETISOC', 'CAPE_POS_MALESTAR', 'CSI_EXPEMOC', 'CSI_AUTOCRIT']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[-1.288611 -1.318311 -0.950999 -0.985517 ... -0.623847 -0.771573 -0.978751 -0.559012]
#  [-0.773567 -1.318311  2.244906  1.56319  ...  0.226703  0.745433  1.316662  0.146098]
#  [-0.430205 -0.764706 -0.391716  0.288837 ...  0.014066 -0.663216  0.168956  0.322375]
#  [ 0.084839 -0.395637 -0.471614 -0.560732 ...  0.014066 -0.446501 -0.022329 -0.382735]
#  [-1.15985   0.157968 -1.030897 -1.197909 ... -1.049122 -0.446501  2.0818   -0.559012]]
# [0 1 0 1 0]

# %%
learn = tabular_learner(data, layers=[100,50], metrics=accuracy)
learn.fit(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.969159</td>
#       <td>0.908196</td>
#       <td>0.724138</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.841928</td>
#       <td>0.840071</td>
#       <td>0.724138</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.764567</td>
#       <td>0.790144</td>
#       <td>0.724138</td>
#       <td>02:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.713222</td>
#       <td>0.732446</td>
#       <td>0.724138</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.651600</td>
#       <td>0.702761</td>
#       <td>0.758621</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.603030</td>
#       <td>0.734447</td>
#       <td>0.689655</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.552984</td>
#       <td>0.704820</td>
#       <td>0.689655</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.510969</td>
#       <td>0.709753</td>
#       <td>0.724138</td>
#       <td>03:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.474802</td>
#       <td>0.779403</td>
#       <td>0.689655</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.438659</td>
#       <td>0.817168</td>
#       <td>0.724138</td>
#       <td>02:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>TRAUMA_AFECTACION</th>
#       <th>CSI_REESTCOGN</th>
#       <th>SCL90_DEPRE</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>CSL90_HOSTIL</th>
#       <th>SCL90_ANSIE</th>
#       <th>ANSIEDADRASGO</th>
#       <th>CSI_RESPROBL</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>CSI_EVITPROBL</th>
#       <th>CSL90_SENS_INT</th>
#       <th>CSI_PENSDESID</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>SCL90_SOMAT</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>SCL90_ANS_FOB</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>CSI_APOYOSOC</th>
#       <th>SCL90_PSICOT</th>
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>ESTRES_PERCIBIDO</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>CSI_RETISOC</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>CSI_EXPEMOC</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.9432</td>
#       <td>-0.5802</td>
#       <td>0.1676</td>
#       <td>0.1826</td>
#       <td>0.2362</td>
#       <td>0.2722</td>
#       <td>0.0405</td>
#       <td>-1.2916</td>
#       <td>0.6933</td>
#       <td>-0.7728</td>
#       <td>0.4778</td>
#       <td>-0.7319</td>
#       <td>-0.1294</td>
#       <td>1.1100</td>
#       <td>-0.0945</td>
#       <td>0.5821</td>
#       <td>0.5898</td>
#       <td>0.8558</td>
#       <td>-1.4423</td>
#       <td>1.1624</td>
#       <td>1.0527</td>
#       <td>-0.1090</td>
#       <td>0.3136</td>
#       <td>0.2267</td>
#       <td>1.0705</td>
#       <td>-0.7875</td>
#       <td>-0.3827</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td