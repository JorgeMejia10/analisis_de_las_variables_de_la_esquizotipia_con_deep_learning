# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 80% de los datos para entrenamiento y un 20% de los datos para validación
valid_idx  =  range ( len ( df ) - 57 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['CSL90_SENS_INT', 'ESTRES_PERCIBIDO', 'CSI_EXPEMOC', 'SCL90_SOMAT', 'SCL90_ANS_FOB', 'CAPE_DEPRE_MALESTAR', 'TRAUMA_FRECUENCIA', 'CSI_AUTOCRIT', 'SCL90_DEPRE', 'TRAUMA_AFECTACION', 'SCL90_OBS_COMP', 'ANSIEDADRASGO', 'SCL90_IDEA_PARAN', 'CAPE_NEG_FREC', 'CSI_REESTCOGN', 'SCL90_ANSIE', 'CSI_RETISOC', 'CSI_PENSDESID', 'CAPE_POSIT_FREC', 'CAPE_DEPRE_FREC', 'CAPE_NEG_MALESTAR', 'CSL90_HOSTIL', 'CAPE_POS_MALESTAR', 'CSI_RESPROBL', 'CSI_EVITPROBL', 'CSI_APOYOSOC', 'SCL90_PSICOT']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[-0.205297  0.160947  0.553012 -0.1643   ... -0.323969 -0.328163 -0.743802  0.0853  ]
#  [ 0.330464 -0.192314 -0.390652  0.80541  ...  1.485515  0.540615 -0.575989  1.002987]
#  [-0.071357  0.396454  0.553012  0.223584 ... -0.525022 -0.110968  0.263079  0.74079 ]
#  [ 0.866226  1.102976 -1.711782 -0.552184 ...  0.6813   -1.196941 -1.079429  0.347496]
#  [-0.874999 -0.07456  -0.390652 -0.843097 ...  0.078139 -1.414136  0.263079 -0.307995]]
# [1 0 0 0 0]

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.019128</td>
#       <td>1.032925</td>
#       <td>0.526316</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.832635</td>
#       <td>0.993931</td>
#       <td>0.596491</td>
#       <td>02:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.734439</td>
#       <td>0.958839</td>
#       <td>0.631579</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.665343</td>
#       <td>0.929095</td>
#       <td>0.631579</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.614374</td>
#       <td>0.895464</td>
#       <td>0.701754</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.569882</td>
#       <td>0.843231</td>
#       <td>0.754386</td>
#       <td>02:41</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.541990</td>
#       <td>0.830260</td>
#       <td>0.736842</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.499076</td>
#       <td>0.824606</td>
#       <td>0.719298</td>
#       <td>02:47</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.456273</td>
#       <td>0.839244</td>
#       <td>0.736842</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.418912</td>
#       <td>0.859831</td>
#       <td>0.736842</td>
#       <td>02:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>CSL90_SENS_INT</th>
#       <th>ESTRES_PERCIBIDO</th>
#       <th>CSI_EXPEMOC</th>
#       <th>SCL90_SOMAT</th>
#       <th>SCL90_ANS_FOB</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>SCL90_DEPRE</th>
#       <th>TRAUMA_AFECTACION</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>ANSIEDADRASGO</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>CSI_REESTCOGN</th>
#       <th>SCL90_ANSIE</th>
#       <th>CSI_RETISOC</th>
#       <th>CSI_PENSDESID</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>CSL90_HOSTIL</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>CSI_RESPROBL</th>
#       <th>CSI_EVITPROBL</th>
#       <th>CSI_APOYOSOC</th>
#       <th>SCL90_PSICOT</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1.0002</td>
#       <td>0.8675</td>
#       <td>-1.7118</td>
#       <td>-0.8431</td>
#       <td>-0.6993</td>
#       <td>0.8637</td>
#       <td>0.2933</td>
#       <td>0.6547</td>
#       <td>-0.0581</td>
#       <td>0.8081</td>
#       <td>0.1981</td>
#       <td>-0.1457</td>
#       <td>1.0269</td>
#       <td>0.3031</td>
#       <td>-0.2256</td>
#       <td>-0.1922</td>
#       <td>-0.1961</td>
#       <td>-0.7051</td>
#       <td>0.6420</td>
#       <td>0.3497</td>
#       <td>0.9705</td>
#       <td>0.4484</td>
#       <td>1.3670</td>
#       <td>-0.3240</td>
#       <td>-0.3282</td>
#       <td>-1.0794</td>
#       <td>0.6097</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       