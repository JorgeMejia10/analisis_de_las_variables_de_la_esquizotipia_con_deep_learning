# %%
from fastai.tabular import *

# %%
path = 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'
path
# Out:
# 'C:/Users/Jorge Mejia/Desktop/analisis_de_las_variables_de_la_esquizotipia_con_deep_learning/analisis_con_dataset_original/'

# %%
df = pd.read_csv(path + 'dataset_esquizotipia_original.csv')
df.head()
# Out:
#    ESTRES_PERCIBIDO  CSI_RESPROBL  CSI_REESTCOGN  CSI_APOYOSOC  CSI_EXPEMOC  \
# 0                23            17              5             0            0
# 1                22            13             11             3           10
# 2                10            20             20            20           16
# 3                 7            12              1             0            7
# 4                31             8              9            17           13
#
#    CSI_EVITPROBL  CSI_PENSDESID  CSI_RETISOC  CSI_AUTOCRIT  ANSIEDADRASGO  \
# 0              7              5           13             2             20
# 1              6             11           17            11             17
# 2             11              8            3             0             20
# 3              4              6            3             1             18
# 4              4             14            2             6             27
#
#    ...  SCL90_PSICOT  CAPE_POSIT_FREC  CAPE_POS_MALESTAR  CAPE_NEG_FREC  \
# 0  ...             0               24                  4             14
# 1  ...             9               22                  2             29
# 2  ...             5               30                  9             29
# 3  ...             0               20                  0             16
# 4  ...            17               35                 13             36
#
#    CAPE_NEG_MALESTAR  CAPE_DEPRE_FREC  CAPE_DEPRE_MALESTAR  TRAUMA_FRECUENCIA  \
# 0                  0                8                    0                  4
# 1                 33               11                    3                  9
# 2                 21               10                    2                 12
# 3                  2                8                    0                  4
# 4                 26               19                   19                 17
#
#    TRAUMA_AFECTACION  SPQ_TOTAL_ESQUIZOT
# 0                  8                   0
# 1                 29                   0
# 2                 25                   1
# 3                 10                   0
# 4                 48                   2
#
# [5 rows x 28 columns]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
# se selecciona un 85% de los datos para entrenamiento y un 15% de los datos para validación
valid_idx  =  range ( len ( df ) - 43 ,  len ( df ))

# %%
# Se define la variable dependiente
dep_var  =  'SPQ_TOTAL_ESQUIZOT'

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs)
print(data.train_ds.cont_names) # `cont_names` defaults to: set(df)-set(cat_names)-{dep_var}
# Out:
# ['TRAUMA_FRECUENCIA', 'SCL90_SOMAT', 'TRAUMA_AFECTACION', 'CSI_APOYOSOC', 'SCL90_ANSIE', 'CAPE_POSIT_FREC', 'CAPE_POS_MALESTAR', 'SCL90_OBS_COMP', 'CSI_EXPEMOC', 'CSI_EVITPROBL', 'ESTRES_PERCIBIDO', 'CAPE_DEPRE_MALESTAR', 'SCL90_ANS_FOB', 'CSL90_HOSTIL', 'ANSIEDADRASGO', 'SCL90_DEPRE', 'CAPE_NEG_FREC', 'CSI_REESTCOGN', 'CAPE_DEPRE_FREC', 'SCL90_IDEA_PARAN', 'SCL90_PSICOT', 'CSI_AUTOCRIT', 'CSL90_SENS_INT', 'CSI_RETISOC', 'CAPE_NEG_MALESTAR', 'CSI_RESPROBL', 'CSI_PENSDESID']

# %%
(cat_x,cont_x),y = next(iter(data.train_dl))
for o in (cat_x, cont_x, y): print(to_np(o[:5]))
# Out:
# [0 0 0 0 0]
# [[ 0.288454 -1.03472   0.763209  1.436165 ... -0.188918  0.505651  0.902934  0.106139]
#  [-0.749281  1.096923 -1.026615  0.083498 ...  0.657297  0.048873 -1.126788 -0.725852]
#  [ 0.854491 -0.840934  1.743351 -0.423752 ... -0.188918  0.231585 -0.314899 -0.060259]
#  [-0.560602  0.612459  0.166601 -0.931002 ... -1.035133  0.140229  1.105907 -1.058649]
#  [ 0.005435 -1.03472  -0.344777  1.774331 ... -1.246687 -1.047394  1.511851  1.270926]]
# [0 2 0 0 0]

# %%
learn = tabular_learner(data, layers=[200,100], metrics=accuracy)
learn.fit(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.967798</td>
#       <td>1.001892</td>
#       <td>0.581395</td>
#       <td>03:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.844696</td>
#       <td>0.964872</td>
#       <td>0.674419</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.730716</td>
#       <td>0.931989</td>
#       <td>0.674419</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.656920</td>
#       <td>0.868594</td>
#       <td>0.674419</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.588492</td>
#       <td>0.805953</td>
#       <td>0.697674</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.540530</td>
#       <td>0.814918</td>
#       <td>0.744186</td>
#       <td>03:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.495648</td>
#       <td>0.849667</td>
#       <td>0.720930</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.450869</td>
#       <td>0.875327</td>
#       <td>0.720930</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.411358</td>
#       <td>0.936500</td>
#       <td>0.697674</td>
#       <td>02:57</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.385076</td>
#       <td>1.055607</td>
#       <td>0.720930</td>
#       <td>02:58</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>TRAUMA_FRECUENCIA</th>
#       <th>SCL90_SOMAT</th>
#       <th>TRAUMA_AFECTACION</th>
#       <th>CSI_APOYOSOC</th>
#       <th>SCL90_ANSIE</th>
#       <th>CAPE_POSIT_FREC</th>
#       <th>CAPE_POS_MALESTAR</th>
#       <th>SCL90_OBS_COMP</th>
#       <th>CSI_EXPEMOC</th>
#       <th>CSI_EVITPROBL</th>
#       <th>ESTRES_PERCIBIDO</th>
#       <th>CAPE_DEPRE_MALESTAR</th>
#       <th>SCL90_ANS_FOB</th>
#       <th>CSL90_HOSTIL</th>
#       <th>ANSIEDADRASGO</th>
#       <th>SCL90_DEPRE</th>
#       <th>CAPE_NEG_FREC</th>
#       <th>CSI_REESTCOGN</th>
#       <th>CAPE_DEPRE_FREC</th>
#       <th>SCL90_IDEA_PARAN</th>
#       <th>SCL90_PSICOT</th>
#       <th>CSI_AUTOCRIT</th>
#       <th>CSL90_SENS_INT</th>
#       <th>CSI_RETISOC</th>
#       <th>CAPE_NEG_MALESTAR</th>
#       <th>CSI_RESPROBL</th>
#       <th>CSI_PENSDESID</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.3719</td>
#       <td>0.5156</td>
#       <td>-0.1317</td>
#       <td>1.6052</td>
#       <td>0.6526</td>
#       <td>-0.1545</td>
#       <td>0.2197</td>
#       <td>0.3242</td>
#       <td>0.3497</td>
#       <td>1.6571</td>
#       <td>1.5861</td>
#       <td>0.4405</td>
#       <td>-0.6880</td>
#       <td>-0.6153</td>
#       <td>0.3519</td>
#       <td>0.8337</td>
#       <td>0.0361</td>
#       <td>-0.3993</td>
#       <td>0.1242</td>
#       <td>-0.8979</td>
#       <td>0.5051</td>
#       <td>2.0858</td>
#       <td>-0.6075</td>
#       <td>-0.8236</td>
#       <td>-0.0425</td>
#       <td>-0.7208</td>
#       <td>0.7717</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td